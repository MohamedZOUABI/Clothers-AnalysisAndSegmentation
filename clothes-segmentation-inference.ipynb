# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 104.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 31.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 84.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import glob
import matplotlib.pyplot as plt
from ultralytics import YOLO

model = YOLO("/kaggle/input/yolo-clothes-seg/YOLO Clothes.pt")

results = model.predict(
    source="/kaggle/input/clothing-seg/test/images",  
    conf=0.5
)

num_to_show = 5  

for r in results[:num_to_show]:
    plt.figure(figsize=(6,6))
    plt.imshow(r.plot()) 
    plt.axis("off")
    plt.show()
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
#
# image 1/109 /kaggle/input/clothing-seg/test/images/003d41dd20f271d27219fe7ee6de727d_jpg.rf.3d641e15b38fd33ceea80cba1ce27cef.jpg: 640x640 1 shirt, 1 shorts, 36.9ms
# image 2/109 /kaggle/input/clothing-seg/test/images/00a1940434d687a785be0acf2b0fbff3_jpg.rf.ad28998030361f63d91b01ea3fcd83ca.jpg: 640x640 1 pants, 1 shirt, 10.4ms
# image 3/109 /kaggle/input/clothing-seg/test/images/045db5fc067cb10b5d705c2afefa5966_jpg.rf.1c4f867c45cbe07c3990fa7e66a8b12b.jpg: 640x640 1 dress, 10.3ms
# image 4/109 /kaggle/input/clothing-seg/test/images/0a4f8205a3b58e70eec99fbbb9422d08_jpg.rf.4abcb1129dcca5d4a8f72a993bbcb2ba.jpg: 640x640 1 dress, 10.2ms
# ...
